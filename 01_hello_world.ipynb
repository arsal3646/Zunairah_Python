# %% [markdown]
# # Python Practice
#
# My first Jupyter Notebook.

# %%
print('Hello, World!')
# Out:
# Hello, World!

# %%
# I am beginner in Python.
# I want to write a simple program that prints "Hello, World!" to the console.

print("Hello, World!")
# Out:
# Hello, World!
